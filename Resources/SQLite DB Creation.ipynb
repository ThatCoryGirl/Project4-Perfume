# %% [markdown]
# This notebook was utilized in the creation of the SQLite database. Localized files saved to a desktop were converted into a .db format and exported to be used globally between team members for the completion of the project. Attempting to run the code will result in errors due to the nature of the original file location, and this notebook simply serves as a reference to the steps that were taken to create the database itself.

# %%
# Import Dependencies
import pandas as pd
import sqlite3

# Step 1: Read CSV file into a DataFrame
csv_file = 'C:/Users/Amanda/Desktop/Analytics/PRoject 4/Resources/perfume_database.csv'
No_Reviews_df = pd.read_csv(csv_file)

# Step 2: Connect to SQLite Database
# Specify the desired path for the SQLite database file
sqlite_file = 'C:/Users/Amanda/Desktop/Analytics/PRoject 4/Resources/perfume.db'

conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

# Step 3: Create Table
table_name = 'No_Reviews'
 # Replace if table exists
df.to_sql(table_name, conn, index=False, if_exists='replace')

# Commit changes and close connection
conn.commit()
conn.close()

# %%
# This is an example of No_Reviews table
No_Reviews_df.head()
# Out:
#           brand                      perfume  launch_year  \
# 0  Aerin Lauder          Rose de Grasse d Or       2017.0
# 1  Calvin Klein                       CK All       2017.0
# 2         Clean  Clean For Men Black Leather       2017.0
# 3         Clean  Clean For Men White Vetiver       2017.0
# 4         Clean              Clean Lovegrass       2017.0
#
#                                   main_accords_dirty  \
# 0  ["woody", "musky", "leather", "patchouli", "ro...
# 1  ["amber", "citrus", "white floral", "animalic"...
# 2  ["fresh spicy", "aromatic", "green", "marine",...
# 3  ["woody", "aromatic", "citrus", "fresh spicy",...
# 4  ["citrus", "white floral", "sweet", "floral", ...
#
#                                                notes  \
# 0  {"middle": null, "base": ["Bulgarian Rose", "P...
# 1  {"middle": ["Citrus Blossom", "Jasmine"], "bas...
# 2  {"middle": ["Juniper", "Mint", "Orchid"], "bas...
# 3  {"middle": ["Vetiver", "Cottonwood (Poplar)", ...
# ...

# %%
# Step 1: Read CSV file into a DataFrame
csv_file = 'C:/Users/Amanda/Desktop/Analytics/PRoject 4/Resources/perfume_data_combined.csv'
df = pd.read_csv(csv_file)

# Step 2: Connect to SQLite Database
# Specify the desired path for the SQLite database file
sqlite_file = 'C:/Users/Amanda/Desktop/Analytics/PRoject 4/Resources/perfume.db'

conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

# Step 3: Create Table
table_name = 'Reviews_Included'
df.to_sql(table_name, conn, index=False, if_exists='replace')  # Replace if table exists

# Commit changes and close connection
conn.commit()
conn.close()

# %%
df.head()
# Out:
#                     name             company  \
# 0          Angels' Share           By Kilian
# 1                 My Way      Giorgio Armani
# 2          Libre Intense  Yves Saint Laurent
# 3        Dior Homme 2020      Christian Dior
# 4  Acqua di Giò Profondo      Giorgio Armani
#
#                                                image         for_gender  \
# 0  https://fimgs.net/mdimg/perfume/375x500.62615.jpg  for women and men
# 1  https://fimgs.net/mdimg/perfume/375x500.62036.jpg          for women
# 2  https://fimgs.net/mdimg/perfume/375x500.62318.jpg          for women
# 3  https://fimgs.net/mdimg/perfume/375x500.58714.jpg            for men
# 4  https://fimgs.net/mdimg/perfume/375x500.59532.jpg            for men
#
#    rating  number_votes                                       main accords  \
# 0    4.31         682.0  {'woody': 100.0, 'sweet': 92.6987, 'warm spicy...
# 1    3.57        1471.0  {'white floral': 100.0, 'citrus': 60.4322, 'tu...
# ...
