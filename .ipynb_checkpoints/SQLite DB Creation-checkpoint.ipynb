# %%
import pandas as pd
import sqlite3

# Step 1: Read CSV file into a DataFrame
csv_file = 'C:/Users/Amanda/Desktop/Analytics/PRoject 4/Resources/perfume_data_combined.csv'
df = pd.read_csv(csv_file)

# Step 2: Connect to SQLite Database
sqlite_file = 'perfume.db'
conn = sqlite3.connect(sqlite_file)
cur = conn.cursor()

# Step 3: Create Table
table_name = 'Reviews_Included'
df.to_sql(table_name, conn, index=False, if_exists='replace')  # Replace if table exists

# Step 4 (Optional): If you want to define the schema explicitly:
# cur.execute('''CREATE TABLE IF NOT EXISTS your_table (
#                 column1_type column1_name,
#                 column2_type column2_name,
#                 ...
#             )''')

# Step 5: Insert Data (Not needed since to_sql already inserts data)

# Commit changes and close connection
conn.commit()
conn.close()

# %%
df.tail()
# Out:
#             name          company  \
# 473  La Capitale          Xerjoff
# 474   DKNY Women      Donna Karan
# 475        Toy 2         Moschino
# 476        Derby         Guerlain
# 477        Aimer  Pascal Morabito
#
#                                                  image         for_gender  \
# 473  https://fimgs.net/mdimg/perfume/375x500.55782.jpg  for women and men
# 474    https://fimgs.net/mdimg/perfume/375x500.504.jpg          for women
# 475  https://fimgs.net/mdimg/perfume/375x500.51589.jpg          for women
# 476  https://fimgs.net/mdimg/perfume/375x500.17119.jpg            for men
# 477  https://fimgs.net/mdimg/perfume/375x500.62798.jpg          for women
#
#      rating  number_votes                                       main accords  \
# 473    4.13         187.0  {'fruity': 100.0, 'sweet': 92.341, 'amber': 85...
# 474    3.87        2285.0  {'citrus': 100.0, 'aromatic': 97.6724, 'green'...
# ...
