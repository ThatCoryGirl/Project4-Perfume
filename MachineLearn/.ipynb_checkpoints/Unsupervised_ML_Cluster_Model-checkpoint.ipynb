# %% [markdown]
# 1. Gather data from SQLite database

# %%
# Import required libraries and dependencies
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
#import dependency for SQLite database
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect("../Resources/perfume.db")

# Create a cursor object to execute SQL queries
cur = conn.cursor()

# %%
# Fetch all rows from the 'Review_Included' table
cur.execute("SELECT * FROM Reviews_Included")

# Fetch all rows from the 'Review_Included' table
rows = cur.fetchall()

# Close the cursor and connection
cur.close()
conn.close()

# %%
# Convert fetched data into a pandas DataFrame
# Get column names
columns = [col[0] for col in cur.description]
perfume_df = pd.DataFrame(rows, columns=columns)

# Display the first few rows of the DataFrame
perfume_df.head()
# Out:
#                     name             company  \
# 0          Angels' Share           By Kilian
# 1                 My Way      Giorgio Armani
# 2          Libre Intense  Yves Saint Laurent
# 3        Dior Homme 2020      Christian Dior
# 4  Acqua di Giò Profondo      Giorgio Armani
#
#                                                image         for_gender  \
# 0  https://fimgs.net/mdimg/perfume/375x500.62615.jpg  for women and men
# 1  https://fimgs.net/mdimg/perfume/375x500.62036.jpg          for women
# 2  https://fimgs.net/mdimg/perfume/375x500.62318.jpg          for women
# 3  https://fimgs.net/mdimg/perfume/375x500.58714.jpg            for men
# 4  https://fimgs.net/mdimg/perfume/375x500.59532.jpg            for men
#
#    rating  number_votes                                       main accords  \
# 0    4.31         682.0  {'woody': 100.0, 'sweet': 92.6987, 'warm spicy...
# 1    3.57        1471.0  {'white floral': 100.0, 'citrus': 60.4322, 'tu...
# 2    4.02         858.0  {'vanilla': 100.0, 'aromatic': 71.4216, 'sweet...
# 3    3.42        1402.0  {'woody': 100.0, 'musky': 72.7229, 'amber': 53...
# 4    4.03         869.0  {'aromatic': 100.0, 'marine': 93.2493, 'citrus...
#
#                                          description  \
# 0  Angels' Share by By Kilian is a Oriental Vanil...
# 1  My Way by Giorgio Armani is a Floral fragrance...
# 2  Libre Intense by Yves Saint Laurent is a Orien...
# 3  Dior Homme 2020 by Christian Dior is a Woody f...
# 4  Acqua di Giò Profondo by Giorgio Armani is a A...
#
#                                            top notes  \
# 0                                         ['Cognac']
# 1                     ['Orange Blossom', 'Bergamot']
# 2        ['Lavender', 'Mandarin Orange', 'Bergamot']
# 3               ['Bergamot', 'Pink Pepper', 'elemi']
# 4  ['Sea Notes', 'Aquozone', 'Bergamot', 'Green M...
#
#                                         middle notes  \
# 0                  ['Cinnamon', 'Tonka Bean', 'Oak']
# 1                     ['Tuberose', 'Indian Jasmine']
# 2  ['Lavender', 'Tunisian Orange Blossom', 'Jasmi...
# 3      ['Cashmere Wood', 'Atlas Cedar', 'Patchouli']
# 4  ['Rosemary', 'Cypress', 'Lavender', 'Mastic or...
#
#                                           base notes  \
# 0               ['Praline', 'Vanilla', 'Sandalwood']
# 1  ['White Musk', 'Madagascar Vanilla', 'Virginia...
# 2  ['Madagascar Vanilla', 'Tonka Bean', 'Ambergri...
# 3   ['Iso E Super', 'Haitian Vetiver', 'White Musk']
# 4    ['Mineral notes', 'Musk', 'Patchouli', 'Amber']
#
#                                            longevity  \
# 0  {'very weak': 21, 'weak': 17, 'moderate': 107,...
# 1  {'very weak': 49, 'weak': 84, 'moderate': 200,...
# 2  {'very weak': 24, 'weak': 12, 'moderate': 103,...
# 3  {'very weak': 125, 'weak': 83, 'moderate': 174...
# 4  {'very weak': 59, 'weak': 66, 'moderate': 188,...
#
#                                              sillage  \
# 0  {'intimate': 40, 'moderate': 187, 'strong': 15...
# 1  {'intimate': 127, 'moderate': 322, 'strong': 2...
# 2  {'intimate': 39, 'moderate': 155, 'strong': 23...
# 3  {'intimate': 214, 'moderate': 370, 'strong': 1...
# 4  {'intimate': 115, 'moderate': 333, 'strong': 1...
#
#                                          gender_vote  \
# 0  {'female': 40, 'more female': 39, 'unisex': 22...
# 1  {'female': 349, 'more female': 21, 'unisex': 4...
# 2  {'female': 162, 'more female': 91, 'unisex': 7...
# 3  {'female': 3, 'more female': 1, 'unisex': 17, ...
# 4  {'female': 3, 'more female': 0, 'unisex': 5, '...
#
#                                          price value
# 0  {'way overpriced': 64, 'overpriced': 143, 'ok'...
# 1  {'way overpriced': 38, 'overpriced': 121, 'ok'...
# 2  {'way overpriced': 11, 'overpriced': 59, 'ok':...
# 3  {'way overpriced': 31, 'overpriced': 59, 'ok':...
# 4  {'way overpriced': 32, 'overpriced': 84, 'ok':...

# %%
# Remove unnecessary columns (at this point we have decided to use the main accords in lieu of the top, middle, and base notes for accuracy)
columns_to_remove = ['image', 'for_gender', 'description', 'gender_vote', 'price value', 'top notes', 'middle notes', 'base notes']

# Remove the specified columns
perfume_df = perfume_df.drop(columns=columns_to_remove)

# Rename the column 'main accords' to 'main_accords' in perfume_df
perfume_df.rename(columns={'main accords': 'main_accords'}, inplace=True)

# Display the DataFrame after dropping the specified columns
perfume_df.head()
# Out:
#                     name             company  rating  number_votes  \
# 0          Angels' Share           By Kilian    4.31         682.0
# 1                 My Way      Giorgio Armani    3.57        1471.0
# 2          Libre Intense  Yves Saint Laurent    4.02         858.0
# 3        Dior Homme 2020      Christian Dior    3.42        1402.0
# 4  Acqua di Giò Profondo      Giorgio Armani    4.03         869.0
#
#                                         main_accords  \
# 0  {'woody': 100.0, 'sweet': 92.6987, 'warm spicy...
# 1  {'white floral': 100.0, 'citrus': 60.4322, 'tu...
# 2  {'vanilla': 100.0, 'aromatic': 71.4216, 'sweet...
# 3  {'woody': 100.0, 'musky': 72.7229, 'amber': 53...
# 4  {'aromatic': 100.0, 'marine': 93.2493, 'citrus...
#
#                                            longevity  \
# 0  {'very weak': 21, 'weak': 17, 'moderate': 107,...
# 1  {'very weak': 49, 'weak': 84, 'moderate': 200,...
# 2  {'very weak': 24, 'weak': 12, 'moderate': 103,...
# 3  {'very weak': 125, 'weak': 83, 'moderate': 174...
# 4  {'very weak': 59, 'weak': 66, 'moderate': 188,...
#
#                                              sillage
# 0  {'intimate': 40, 'moderate': 187, 'strong': 15...
# 1  {'intimate': 127, 'moderate': 322, 'strong': 2...
# 2  {'intimate': 39, 'moderate': 155, 'strong': 23...
# 3  {'intimate': 214, 'moderate': 370, 'strong': 1...
# 4  {'intimate': 115, 'moderate': 333, 'strong': 1...

# %% [markdown]
# 2. Preprocess dataset for it to be useful for the model. Perfumes that have a rating below 3.59 and have less than or equal to 100 votes have been removed from the dataset. Main accords have been divided for each perfume and a column has been added for the scent strength. The perfumes have been duplicated based on the number of scents in each one and we have 3393 entries for the model to work with at this point. Data with NaN values have been removed. So we have 2655 entries to work with for the model.

# %%
# Define the threshold for removing rows based on rating
rating_threshold = 3.59

# Filter the DataFrame to exclude rows with ratings at or below the threshold
perfume_df = perfume_df[perfume_df['rating'] > rating_threshold]

# Display the DataFrame after removing rows
print(perfume_df)
# Out:
#                            name             company  rating  number_votes  \
# 0                 Angels' Share           By Kilian    4.31         682.0
# 2                 Libre Intense  Yves Saint Laurent    4.02         858.0
# 4         Acqua di Giò Profondo      Giorgio Armani    4.03         869.0
# 5             Le Male Le Parfum  Jean Paul Gaultier    4.26         690.0
# 6    Beau De Jour Eau de Parfum            Tom Ford    4.25         729.0
# ..                          ...                 ...     ...           ...
# 473                 La Capitale             Xerjoff    4.13         187.0
# 474                  DKNY Women         Donna Karan    3.87        2285.0
# 475                       Toy 2            Moschino    3.80         940.0
# 476                       Derby            Guerlain    4.38         389.0
# 477                       Aimer     Pascal Morabito    3.71           7.0
#
#                                           main_accords  \
# 0    {'woody': 100.0, 'sweet': 92.6987, 'warm spicy...
# 2    {'vanilla': 100.0, 'aromatic': 71.4216, 'sweet...
# 4    {'aromatic': 100.0, 'marine': 93.2493, 'citrus...
# 5    {'warm spicy': 100.0, 'vanilla': 72.2173, 'aro...
# 6    {'aromatic': 100.0, 'fresh spicy': 94.7562, 'l...
# ..                                                 ...
# 473  {'fruity': 100.0, 'sweet': 92.341, 'amber': 85...
# 474  {'citrus': 100.0, 'aromatic': 97.6724, 'green'...
# 475  {'fruity': 100.0, 'floral': 73.9229, 'fresh': ...
# 476  {'leather': 100.0, 'warm spicy': 95.3529, 'woo...
# 477  {'sweet': 100.0, 'warm spicy': 69.375, 'citrus...
#
#                                              longevity  \
# 0    {'very weak': 21, 'weak': 17, 'moderate': 107,...
# 2    {'very weak': 24, 'weak': 12, 'moderate': 103,...
# 4    {'very weak': 59, 'weak': 66, 'moderate': 188,...
# 5    {'very weak': 18, 'weak': 31, 'moderate': 129,...
# 6    {'very weak': 30, 'weak': 19, 'moderate': 88, ...
# ..                                                 ...
# 473  {'very weak': 5, 'weak': 9, 'moderate': 20, 'l...
# 474  {'very weak': 23, 'weak': 44, 'moderate': 190,...
# 475  {'very weak': 54, 'weak': 78, 'moderate': 147,...
# 476  {'very weak': 6, 'weak': 18, 'moderate': 26, '...
# 477  {'very weak': 0, 'weak': 1, 'moderate': 0, 'lo...
#
#                                                sillage
# 0    {'intimate': 40, 'moderate': 187, 'strong': 15...
# 2    {'intimate': 39, 'moderate': 155, 'strong': 23...
# 4    {'intimate': 115, 'moderate': 333, 'strong': 1...
# 5    {'intimate': 80, 'moderate': 262, 'strong': 17...
# 6    {'intimate': 45, 'moderate': 190, 'strong': 19...
# ..                                                 ...
# 473  {'intimate': 22, 'moderate': 36, 'strong': 53,...
# 474  {'intimate': 71, 'moderate': 244, 'strong': 21...
# 475  {'intimate': 135, 'moderate': 200, 'strong': 1...
# 476  {'intimate': 29, 'moderate': 69, 'strong': 93,...
# 477  {'intimate': 0, 'moderate': 2, 'strong': 0, 'e...
#
# [426 rows x 7 columns]

# %%
# Define the threshold for removing rows based on number of votes
votes_threshold = 100

# Filter the DataFrame to exclude rows with number of votes less than the threshold
perfume_df = perfume_df[perfume_df['number_votes'] >= votes_threshold]

# Display the DataFrame after removing rows
print(perfume_df)
# Out:
#                            name             company  rating  number_votes  \
# 0                 Angels' Share           By Kilian    4.31         682.0
# 2                 Libre Intense  Yves Saint Laurent    4.02         858.0
# 4         Acqua di Giò Profondo      Giorgio Armani    4.03         869.0
# 5             Le Male Le Parfum  Jean Paul Gaultier    4.26         690.0
# 6    Beau De Jour Eau de Parfum            Tom Ford    4.25         729.0
# ..                          ...                 ...     ...           ...
# 472                Laudano Nero     Tiziana Terenzi    4.13        1693.0
# 473                 La Capitale             Xerjoff    4.13         187.0
# 474                  DKNY Women         Donna Karan    3.87        2285.0
# 475                       Toy 2            Moschino    3.80         940.0
# 476                       Derby            Guerlain    4.38         389.0
#
#                                           main_accords  \
# 0    {'woody': 100.0, 'sweet': 92.6987, 'warm spicy...
# 2    {'vanilla': 100.0, 'aromatic': 71.4216, 'sweet...
# 4    {'aromatic': 100.0, 'marine': 93.2493, 'citrus...
# 5    {'warm spicy': 100.0, 'vanilla': 72.2173, 'aro...
# 6    {'aromatic': 100.0, 'fresh spicy': 94.7562, 'l...
# ..                                                 ...
# 472  {'woody': 100.0, 'amber': 93.699, 'smoky': 68....
# 473  {'fruity': 100.0, 'sweet': 92.341, 'amber': 85...
# 474  {'citrus': 100.0, 'aromatic': 97.6724, 'green'...
# 475  {'fruity': 100.0, 'floral': 73.9229, 'fresh': ...
# 476  {'leather': 100.0, 'warm spicy': 95.3529, 'woo...
#
#                                              longevity  \
# 0    {'very weak': 21, 'weak': 17, 'moderate': 107,...
# 2    {'very weak': 24, 'weak': 12, 'moderate': 103,...
# 4    {'very weak': 59, 'weak': 66, 'moderate': 188,...
# 5    {'very weak': 18, 'weak': 31, 'moderate': 129,...
# 6    {'very weak': 30, 'weak': 19, 'moderate': 88, ...
# ..                                                 ...
# 472  {'very weak': 41, 'weak': 38, 'moderate': 84, ...
# 473  {'very weak': 5, 'weak': 9, 'moderate': 20, 'l...
# 474  {'very weak': 23, 'weak': 44, 'moderate': 190,...
# 475  {'very weak': 54, 'weak': 78, 'moderate': 147,...
# 476  {'very weak': 6, 'weak': 18, 'moderate': 26, '...
#
#                                                sillage
# 0    {'intimate': 40, 'moderate': 187, 'strong': 15...
# 2    {'intimate': 39, 'moderate': 155, 'strong': 23...
# 4    {'intimate': 115, 'moderate': 333, 'strong': 1...
# 5    {'intimate': 80, 'moderate': 262, 'strong': 17...
# 6    {'intimate': 45, 'moderate': 190, 'strong': 19...
# ..                                                 ...
# 472  {'intimate': 94, 'moderate': 245, 'strong': 42...
# 473  {'intimate': 22, 'moderate': 36, 'strong': 53,...
# 474  {'intimate': 71, 'moderate': 244, 'strong': 21...
# 475  {'intimate': 135, 'moderate': 200, 'strong': 1...
# 476  {'intimate': 29, 'moderate': 69, 'strong': 93,...
#
# [389 rows x 7 columns]

# %%
# Rename the DataFrame to reflect its cleaned state
# Make a copy to preserve the original DataFrame
cleaned_perfume_df = perfume_df.copy()
cleaned_perfume_df
# Out:
#                            name             company  rating  number_votes  \
# 0                 Angels' Share           By Kilian    4.31         682.0
# 2                 Libre Intense  Yves Saint Laurent    4.02         858.0
# 4         Acqua di Giò Profondo      Giorgio Armani    4.03         869.0
# 5             Le Male Le Parfum  Jean Paul Gaultier    4.26         690.0
# 6    Beau De Jour Eau de Parfum            Tom Ford    4.25         729.0
# ..                          ...                 ...     ...           ...
# 472                Laudano Nero     Tiziana Terenzi    4.13        1693.0
# 473                 La Capitale             Xerjoff    4.13         187.0
# 474                  DKNY Women         Donna Karan    3.87        2285.0
# 475                       Toy 2            Moschino    3.80         940.0
# 476                       Derby            Guerlain    4.38         389.0
#
#                                           main_accords  \
# 0    {'woody': 100.0, 'sweet': 92.6987, 'warm spicy...
# 2    {'vanilla': 100.0, 'aromatic': 71.4216, 'sweet...
# 4    {'aromatic': 100.0, 'marine': 93.2493, 'citrus...
# 5    {'warm spicy': 100.0, 'vanilla': 72.2173, 'aro...
# 6    {'aromatic': 100.0, 'fresh spicy': 94.7562, 'l...
# ..                                                 ...
# 472  {'woody': 100.0, 'amber': 93.699, 'smoky': 68....
# 473  {'fruity': 100.0, 'sweet': 92.341, 'amber': 85...
# 474  {'citrus': 100.0, 'aromatic': 97.6724, 'green'...
# 475  {'fruity': 100.0, 'floral': 73.9229, 'fresh': ...
# 476  {'leather': 100.0, 'warm spicy': 95.3529, 'woo...
#
#                                              longevity  \
# 0    {'very weak': 21, 'weak': 17, 'moderate': 107,...
# 2    {'very weak': 24, 'weak': 12, 'moderate': 103,...
# 4    {'very weak': 59, 'weak': 66, 'moderate': 188,...
# 5    {'very weak': 18, 'weak': 31, 'moderate': 129,...
# 6    {'very weak': 30, 'weak': 19, 'moderate': 88, ...
# ..                                                 ...
# 472  {'very weak': 41, 'weak': 38, 'moderate': 84, ...
# 473  {'very weak': 5, 'weak': 9, 'moderate': 20, 'l...
# 474  {'very weak': 23, 'weak': 44, 'moderate': 190,...
# 475  {'very weak': 54, 'weak': 78, 'moderate': 147,...
# 476  {'very weak': 6, 'weak': 18, 'moderate': 26, '...
#
#                                                sillage
# 0    {'intimate': 40, 'moderate': 187, 'strong': 15...
# 2    {'intimate': 39, 'moderate': 155, 'strong': 23...
# 4    {'intimate': 115, 'moderate': 333, 'strong': 1...
# 5    {'intimate': 80, 'moderate': 262, 'strong': 17...
# 6    {'intimate': 45, 'moderate': 190, 'strong': 19...
# ..                                                 ...
# 472  {'intimate': 94, 'moderate': 245, 'strong': 42...
# 473  {'intimate': 22, 'moderate': 36, 'strong': 53,...
# 474  {'intimate': 71, 'moderate': 244, 'strong': 21...
# 475  {'intimate': 135, 'moderate': 200, 'strong': 1...
# 476  {'intimate': 29, 'moderate': 69, 'strong': 93,...
#
# [389 rows x 7 columns]

# %%
print(cleaned_perfume_df.columns)
# Out:
# Index(['name', 'company', 'rating', 'number_votes', 'main_accords',
#        'longevity', 'sillage'],
#       dtype='object')

# %%
# Use dependency specifically for specialty parsing https://docs.python.org/3/library/ast.html
import ast

#Working to create a new entry for each scent creating multiple entries for each perfume based on the number of scents in it
# Parse the string representations of dictionaries in 'main accords' into separate columns
cleaned_perfume_df = cleaned_perfume_df.copy()

# Parse the string representations of dictionaries into actual dictionaries
cleaned_perfume_df['main_accords'] = cleaned_perfume_df['main_accords'].apply(ast.literal_eval)

# Expand the 'main_accords' column into separate columns
main_accords_df = pd.json_normalize(cleaned_perfume_df['main_accords'])

# Concatenate the expanded 'main_accords' dataframe with the original dataframe
cleaned_perfume_df = pd.concat([cleaned_perfume_df, main_accords_df], axis=1)

# Drop the original 'main_accords' column
cleaned_perfume_df.drop(columns=['main_accords'], inplace=True)

# Using cleaned_perfume_df
cleaned_perfume_df = cleaned_perfume_df.copy()

# Create a dataframe with 'name' and 'company' columns, along with each scent in 'main_accords' as a separate row
scent_df = cleaned_perfume_df[['name', 'company', 'woody', 'sweet', 'warm spicy', 'vanilla', 'cinnamon', 'amber', 'powdery', 'lactonic', 'aromatic']].melt(id_vars=['name', 'company'], var_name='scent', value_name='scent_strength').dropna()

# preview df
scent_df.head()
# Out:
#                          name             company  scent  scent_strength
# 0               Angels' Share           By Kilian  woody        100.0000
# 1               Libre Intense  Yves Saint Laurent  woody         67.7451
# 2       Acqua di Giò Profondo      Giorgio Armani  woody         62.7869
# 3           Le Male Le Parfum  Jean Paul Gaultier  woody         60.2007
# 4  Beau De Jour Eau de Parfum            Tom Ford  woody         52.3889

# %%
# Create a copy of the dataframe
cleaned_perfume_df_copy = cleaned_perfume_df.copy()

# Melt the dataframe to have each scent as its own row
cleaned_perfume_df_melted = cleaned_perfume_df_copy.melt(id_vars=['name', 'company', 'rating', 'number_votes', 'longevity', 'sillage'], var_name='scent', value_name='scent_strength')

# Drop rows with NaN values in the 'scent_strength' column
cleaned_perfume_df_melted = cleaned_perfume_df_melted.dropna(subset=['scent_strength'])

# Reset the index
cleaned_perfume_df_melted.reset_index(drop=True, inplace=True)

# Display the resulting dataframe
cleaned_perfume_df_melted
# Out:
#                             name             company  rating  number_votes  \
# 0                  Angels' Share           By Kilian    4.31         682.0
# 1                  Libre Intense  Yves Saint Laurent    4.02         858.0
# 2          Acqua di Giò Profondo      Giorgio Armani    4.03         869.0
# 3              Le Male Le Parfum  Jean Paul Gaultier    4.26         690.0
# 4     Beau De Jour Eau de Parfum            Tom Ford    4.25         729.0
# ...                          ...                 ...     ...           ...
# 3388                         NaN                 NaN     NaN           NaN
# 3389                 Chanel N°22              Chanel    4.26        1208.0
# 3390                         NaN                 NaN     NaN           NaN
# 3391                         NaN                 NaN     NaN           NaN
# 3392  Un Jardin Apres la Mousson              Hermès    3.98        3208.0
#
#                                               longevity  \
# 0     {'very weak': 21, 'weak': 17, 'moderate': 107,...
# 1     {'very weak': 24, 'weak': 12, 'moderate': 103,...
# 2     {'very weak': 59, 'weak': 66, 'moderate': 188,...
# 3     {'very weak': 18, 'weak': 31, 'moderate': 129,...
# 4     {'very weak': 30, 'weak': 19, 'moderate': 88, ...
# ...                                                 ...
# 3388                                                NaN
# 3389  {'very weak': 21, 'weak': 18, 'moderate': 72, ...
# 3390                                                NaN
# 3391                                                NaN
# 3392  {'very weak': 55, 'weak': 135, 'moderate': 292...
#
#                                                 sillage      scent  \
# 0     {'intimate': 40, 'moderate': 187, 'strong': 15...      woody
# 1     {'intimate': 39, 'moderate': 155, 'strong': 23...      woody
# 2     {'intimate': 115, 'moderate': 333, 'strong': 1...      woody
# 3     {'intimate': 80, 'moderate': 262, 'strong': 17...      woody
# 4     {'intimate': 45, 'moderate': 190, 'strong': 19...      woody
# ...                                                 ...        ...
# 3388                                                NaN    conifer
# 3389  {'intimate': 45, 'moderate': 124, 'strong': 11...  Champagne
# 3390                                                NaN    camphor
# 3391                                                NaN     savory
# 3392  {'intimate': 186, 'moderate': 414, 'strong': 1...      vodka
#
#       scent_strength
# 0           100.0000
# 1            67.7451
# 2            62.7869
# 3            60.2007
# 4            52.3889
# ...              ...
# 3388         57.7621
# 3389         62.1377
# 3390         46.5055
# 3391         84.0410
# 3392         98.8511
#
# [3393 rows x 8 columns]

# %% [markdown]
# 3. Specific data cleaning for a clustering model begins here.

# %%
# Drop 'longevity' and 'sillage' columns as they are not useful for the clustering model
cleaned_perfume_df_melted.drop(['longevity', 'sillage'], axis=1, inplace=True)

# Display the resulting dataframe
print(cleaned_perfume_df_melted)
# Out:
#                             name             company  rating  number_votes  \
# 0                  Angels' Share           By Kilian    4.31         682.0
# 1                  Libre Intense  Yves Saint Laurent    4.02         858.0
# 2          Acqua di Giò Profondo      Giorgio Armani    4.03         869.0
# 3              Le Male Le Parfum  Jean Paul Gaultier    4.26         690.0
# 4     Beau De Jour Eau de Parfum            Tom Ford    4.25         729.0
# ...                          ...                 ...     ...           ...
# 3388                         NaN                 NaN     NaN           NaN
# 3389                 Chanel N°22              Chanel    4.26        1208.0
# 3390                         NaN                 NaN     NaN           NaN
# 3391                         NaN                 NaN     NaN           NaN
# 3392  Un Jardin Apres la Mousson              Hermès    3.98        3208.0
#
#           scent  scent_strength
# 0         woody        100.0000
# 1         woody         67.7451
# 2         woody         62.7869
# 3         woody         60.2007
# 4         woody         52.3889
# ...         ...             ...
# 3388    conifer         57.7621
# 3389  Champagne         62.1377
# 3390    camphor         46.5055
# 3391     savory         84.0410
# 3392      vodka         98.8511
#
# [3393 rows x 6 columns]

# %%
# Sort the dataframe by the 'name' column in alphabetical order
cleaned_perfume_df_melted_sorted = cleaned_perfume_df_melted.sort_values(by='name')

# Reset the index
cleaned_perfume_df_melted_sorted.reset_index(drop=True, inplace=True)

# Drop rows with NaN values in the 'name' column
cleaned_perfume_df_melted_sorted.dropna(subset=['name'], inplace=True)

# Display the resulting dataframe
cleaned_perfume_df_melted_sorted
# Out:
#                              name         company  rating  number_votes  \
# 0     02 L'Air du Desert Marocain  Tauer Perfumes    4.43        4568.0
# 1     02 L'Air du Desert Marocain  Tauer Perfumes    4.43        4568.0
# 2     02 L'Air du Desert Marocain  Tauer Perfumes    4.43        4568.0
# 3     02 L'Air du Desert Marocain  Tauer Perfumes    4.43        4568.0
# 4     02 L'Air du Desert Marocain  Tauer Perfumes    4.43        4568.0
# ...                           ...             ...     ...           ...
# 2650                 Zahrat Hawai        Al-Rehab    3.81         212.0
# 2651                 Zahrat Hawai        Al-Rehab    3.81         212.0
# 2652                 Zahrat Hawai        Al-Rehab    3.81         212.0
# 2653                 Zahrat Hawai        Al-Rehab    3.81         212.0
# 2654                 Zahrat Hawai        Al-Rehab    3.81         212.0
#
#              scent  scent_strength
# 0       warm spicy        100.0000
# 1            musky         45.1861
# 2            green         70.2955
# 3            woody         55.8338
# 4         aromatic         67.0314
# ...            ...             ...
# 2650      aromatic         61.3975
# 2651  white floral         61.2162
# 2652   fresh spicy         47.5000
# 2653        floral         76.5721
# 2654        herbal        100.0000
#
# [2655 rows x 6 columns]

# %%
# Merge 'name' and 'company' into one column
cleaned_perfume_df_melted_sorted['perfume'] = cleaned_perfume_df_melted_sorted['name'] + ' - ' + cleaned_perfume_df_melted_sorted['company']

# Drop the 'name' and 'company' columns
cleaned_perfume_df_melted_sorted.drop(columns=['name', 'company'], inplace=True)

# Set the merged column as the index
cleaned_perfume_df_melted_sorted.set_index('perfume', inplace=True)

# Display the resulting dataframe
cleaned_perfume_df_melted_sorted
# Out:
#                                               rating  number_votes  \
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes    4.43        4568.0
# 02 L'Air du Desert Marocain - Tauer Perfumes    4.43        4568.0
# 02 L'Air du Desert Marocain - Tauer Perfumes    4.43        4568.0
# 02 L'Air du Desert Marocain - Tauer Perfumes    4.43        4568.0
# 02 L'Air du Desert Marocain - Tauer Perfumes    4.43        4568.0
# ...                                              ...           ...
# Zahrat Hawai - Al-Rehab                         3.81         212.0
# Zahrat Hawai - Al-Rehab                         3.81         212.0
# Zahrat Hawai - Al-Rehab                         3.81         212.0
# Zahrat Hawai - Al-Rehab                         3.81         212.0
# Zahrat Hawai - Al-Rehab                         3.81         212.0
#
#                                                      scent  scent_strength
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes    warm spicy        100.0000
# 02 L'Air du Desert Marocain - Tauer Perfumes         musky         45.1861
# 02 L'Air du Desert Marocain - Tauer Perfumes         green         70.2955
# 02 L'Air du Desert Marocain - Tauer Perfumes         woody         55.8338
# 02 L'Air du Desert Marocain - Tauer Perfumes      aromatic         67.0314
# ...                                                    ...             ...
# Zahrat Hawai - Al-Rehab                           aromatic         61.3975
# Zahrat Hawai - Al-Rehab                       white floral         61.2162
# Zahrat Hawai - Al-Rehab                        fresh spicy         47.5000
# Zahrat Hawai - Al-Rehab                             floral         76.5721
# Zahrat Hawai - Al-Rehab                             herbal        100.0000
#
# [2655 rows x 4 columns]

# %% [markdown]
# 4. Machine Model creation starts here.

# %%
#Simplify dataframe name for model use
perfume_model_df = cleaned_perfume_df_melted_sorted.copy()

# %%
print(type(perfume_model_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Import specific dependencies for this block
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Simplify dataframe name
perfume_model_df = cleaned_perfume_df_melted_sorted.copy()

# Select numerical features for normalization
numerical_features = ['rating', 'number_votes', 'scent_strength']

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the numerical features
perfume_model_df[numerical_features] = scaler.fit_transform(perfume_model_df[numerical_features])

# Display the resulting DataFrame
perfume_model_df
# Out:
#                                                 rating  number_votes  \
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# ...                                                ...           ...
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
#
#                                                      scent  scent_strength
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes    warm spicy        1.825294
# 02 L'Air du Desert Marocain - Tauer Perfumes         musky       -1.316633
# 02 L'Air du Desert Marocain - Tauer Perfumes         green        0.122635
# 02 L'Air du Desert Marocain - Tauer Perfumes         woody       -0.706308
# 02 L'Air du Desert Marocain - Tauer Perfumes      aromatic       -0.064462
# ...                                                    ...             ...
# Zahrat Hawai - Al-Rehab                           aromatic       -0.387397
# Zahrat Hawai - Al-Rehab                       white floral       -0.397789
# Zahrat Hawai - Al-Rehab                        fresh spicy       -1.184000
# Zahrat Hawai - Al-Rehab                             floral        0.482410
# Zahrat Hawai - Al-Rehab                             herbal        1.825294
#
# [2655 rows x 4 columns]

# %%
# Selecting all columns except 'scent' as features for clustering
X = perfume_model_df.drop(columns=['scent'])

# Calculate the sum of squared distances for different values of k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)

# Create a DataFrame to store the elbow curve data
elbow_curve_data = pd.DataFrame({'k': range(1, 11), 'inertia': sse})

# Plot the elbow curve using hvplot
elbow_curve_original = elbow_curve_data.hvplot.line(
    x='k', 
    y='inertia', 
    title='Original Elbow Curve', 
    xlabel='Number of Clusters (k)',
    ylabel='Sum of Squared Distances',
    xticks=list(range(1, 11))
)

# Show the line chart
elbow_curve_original
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# The best value for k is 4 based on this elbow curve.

# %%
# Selecting all columns except 'scent' as features for clustering
X = perfume_model_df.drop(columns=['scent'])

# Define the optimal number of clusters
k = 4

# Initialize KMeans with the optimal number of clusters (k)
kmeans = KMeans(n_clusters=k)

# Fit KMeans to the data
kmeans.fit(X)

# Get cluster labels
cluster_labels = kmeans.labels_

# Add cluster labels to the DataFrame
perfume_model_df['cluster'] = cluster_labels

# Display the resulting DataFrame
print(perfume_model_df)
# Out:
#                                                 rating  number_votes  \
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.539120      0.483098
# ...                                                ...           ...
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
# Zahrat Hawai - Al-Rehab                      -1.361101     -0.857486
#
#                                                      scent  scent_strength  \
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes    warm spicy        1.825294
# 02 L'Air du Desert Marocain - Tauer Perfumes         musky       -1.316633
# 02 L'Air du Desert Marocain - Tauer Perfumes         green        0.122635
# 02 L'Air du Desert Marocain - Tauer Perfumes         woody       -0.706308
# 02 L'Air du Desert Marocain - Tauer Perfumes      aromatic       -0.064462
# ...                                                    ...             ...
# Zahrat Hawai - Al-Rehab                           aromatic       -0.387397
# Zahrat Hawai - Al-Rehab                       white floral       -0.397789
# Zahrat Hawai - Al-Rehab                        fresh spicy       -1.184000
# Zahrat Hawai - Al-Rehab                             floral        0.482410
# Zahrat Hawai - Al-Rehab                             herbal        1.825294
#
#                                               cluster
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes        3
# 02 L'Air du Desert Marocain - Tauer Perfumes        1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1
# ...                                               ...
# Zahrat Hawai - Al-Rehab                             0
# Zahrat Hawai - Al-Rehab                             0
# Zahrat Hawai - Al-Rehab                             0
# Zahrat Hawai - Al-Rehab                             0
# Zahrat Hawai - Al-Rehab                             3
#
# [2655 rows x 5 columns]

# %% [markdown]
# The random_state = 42 because 42 is absolutely the answer to the meaning of life, the universe, and everything.

# %%
# Initialize KMeans with the optimal number of clusters (k) and random_state
kmeans = KMeans(n_clusters=k, random_state=42)

# Print the initialized KMeans model
print(kmeans)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# Fit the K-Means model using the scaled data
kmeans.fit(X)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict clusters for the scaled data
cluster_predictions = kmeans.predict(X)

# Print the resulting array of cluster values
cluster_predictions
# Out:
# array([2, 1, 1, ..., 0, 0, 2])

# %%
# Create a copy of the DataFrame
perfume_model_df_copy = perfume_model_df.copy()

# %%
# Add a new column 'predicted_cluster' to the DataFrame with the predicted clusters
perfume_model_df['predicted_cluster'] = cluster_predictions

# Display sample data from the DataFrame
perfume_model_df.head()
# Out:
#                                                rating  number_votes  \
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.53912      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.53912      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.53912      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.53912      0.483098
# 02 L'Air du Desert Marocain - Tauer Perfumes  1.53912      0.483098
#
#                                                    scent  scent_strength  \
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes  warm spicy        1.825294
# 02 L'Air du Desert Marocain - Tauer Perfumes       musky       -1.316633
# 02 L'Air du Desert Marocain - Tauer Perfumes       green        0.122635
# 02 L'Air du Desert Marocain - Tauer Perfumes       woody       -0.706308
# 02 L'Air du Desert Marocain - Tauer Perfumes    aromatic       -0.064462
#
#                                               cluster  predicted_cluster
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes        3                  2
# 02 L'Air du Desert Marocain - Tauer Perfumes        1                  1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1                  1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1                  1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1                  1

# %%
# Create a scatter plot
original_scatter_plot = perfume_model_df.hvplot.scatter(
    x='rating',
    y='number_votes',
    c='predicted_cluster',
    cmap=['blue', 'pink', 'red', 'purple'],
    colorbar=False,
    title='Original Scatter Plot with Predicted Clusters',
    xlabel='Rating',
    ylabel='Number of Votes',
    scatter_common_params = {
    'legend': 'top_right',
    'width': 400,
    'height': 300,
    'grid': True
})

# Show the scatter plot
original_scatter_plot
# Out:
# WARNING:param.main: scatter_common_params option not found for scatter plot with bokeh; similar options include: []
# :Scatter   [rating]   (number_votes,predicted_cluster)

# %% [markdown]
# 5. Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`
pca = PCA(n_components=3)

# %%
# Use the PCA model with fit_transform to reduce to three principal components
pca_features = pca.fit_transform(X)

# Create a DataFrame with the transformed features
pca_df = pd.DataFrame(data=pca_features, columns=[f'PCA{i}' for i in range(1, 4)])

# Display the first five rows of the transformed DataFrame
pca_df.head()
# Out:
#        PCA1      PCA2      PCA3
# 0 -1.096890  1.638041  1.430953
# 1 -0.467982 -1.440299  1.429101
# 2 -0.756075 -0.030159  1.429949
# 3 -0.590149 -0.842326  1.429461
# 4 -0.718625 -0.213470  1.429839

# %%
# Retrieve the explained variance ratios from the fitted PCA model
explained_variance_ratios = pca.explained_variance_ratio_

# Calculate the total explained variance
total_explained_variance = explained_variance_ratios.sum()

# Print the explained variance ratios
print("Explained Variance Ratios:")
for i, explained_variance_ratio in enumerate(explained_variance_ratios):
    print(f"PCA{i + 1}: {explained_variance_ratio:.4f}")

# Print the total explained variance
print(f"\nTotal Explained Variance: {total_explained_variance:.4f}")
# Out:
# Explained Variance Ratios:
# PCA1: 0.4162
# PCA2: 0.3299
# PCA3: 0.2539
#
# Total Explained Variance: 1.0000

# %% [markdown]
# What is the total explained variance of the 3 principal components? 100%

# %%
# Creating a DataFrame with the PCA data
pca_columns = ['PCA1', 'PCA2', 'PCA3']
pca_data_df = pd.DataFrame(pca_df, columns=pca_columns)

# Copy the perfume names from the original data
pca_data_df['perfume'] = perfume_model_df.index

# Set the perfume column as index
pca_data_df.set_index('perfume', inplace=True)

# Display sample data
pca_data_df.head()
# Out:
#                                                   PCA1      PCA2      PCA3
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes -1.096890  1.638041  1.430953
# 02 L'Air du Desert Marocain - Tauer Perfumes -0.467982 -1.440299  1.429101
# 02 L'Air du Desert Marocain - Tauer Perfumes -0.756075 -0.030159  1.429949
# 02 L'Air du Desert Marocain - Tauer Perfumes -0.590149 -0.842326  1.429461
# 02 L'Air du Desert Marocain - Tauer Perfumes -0.718625 -0.213470  1.429839

# %% [markdown]
# 6. Find the best value for k using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
k_values_pca = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia_values_pca = []

# Create a for loop to compute the inertia with each possible value of k
for k in range(1, 12):
    # Create a KMeans model using the loop counter for the n_clusters
    kmeans = KMeans(n_clusters=k)
    
    # Fit the model to the data
    kmeans.fit(X)
    
    # Append the model.inertia_ to the inertia list
    inertia_values_pca.append(kmeans.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data_pca = {
    'Number of Clusters (k)': range(1, 12),
    'Sum of Squared Distances': inertia_values_pca
}

# Create a DataFrame with the data to plot the Elbow curve
pca_elbow_df = pd.DataFrame(elbow_data_pca)

# Display the DataFrame
pca_elbow_df
# Out:
#     Number of Clusters (k)  Sum of Squared Distances
# 0                        1               7965.000000
# 1                        2               5872.030223
# 2                        3               4168.012705
# 3                        4               3028.177788
# 4                        5               2617.230968
# 5                        6               2325.328990
# 6                        7               2073.238227
# 7                        8               1896.863104
# 8                        9               1731.144236
# 9                       10               1604.169792
# 10                      11               1484.965216

# %%
# Calculate the sum of squared distances for different values of k using PCA data
sse_pca = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(pca_df)
    sse_pca.append(kmeans.inertia_)

# Create a DataFrame to store the elbow curve data for PCA
elbow_curve_data_pca = pd.DataFrame({'k': range(1, 11), 'inertia': sse_pca})

# Plot the elbow curve using hvplot for PCA
elbow_curve_pca = elbow_curve_data_pca.hvplot.line(
    x='k', 
    y='inertia', 
    title='PCA Elbow Curve', 
    xlabel='Number of Clusters (k)',
    ylabel='Sum of Squared Distances',
    xticks=list(range(1, 11))
)

# Show the line chart for PCA
elbow_curve_pca
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# The best value for k when using the PCA data is: 4
#
# Does the best k value change between the PCA Data and the Original Data? No

# %% [markdown]
# 7. Cluster Notes with K-means using the PCA Data

# %%
# Initialize the K-Means model using the best value for k
kmeans = KMeans(n_clusters=4, random_state=42)

# %%
# Fit the K-Means model using the PCA data
kmeans.fit(pca_df)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the notes using the PCA data
clusters = kmeans.predict(pca_df)

# Print the resulting array of cluster values
clusters
# Out:
# array([2, 1, 1, ..., 0, 0, 2])

# %%
# Create a copy of the DataFrame with the PCA data
pca_cluster_df = pca_data_df.copy()

# Add a new column to the DataFrame with the predicted clusters
pca_cluster_df['Cluster'] = kmeans.fit_predict(pca_data_df)

# Display sample data
pca_cluster_df.head()
# Out:
#                                                   PCA1      PCA2      PCA3  \
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes -1.096890  1.638041  1.430953
# 02 L'Air du Desert Marocain - Tauer Perfumes -0.467982 -1.440299  1.429101
# 02 L'Air du Desert Marocain - Tauer Perfumes -0.756075 -0.030159  1.429949
# 02 L'Air du Desert Marocain - Tauer Perfumes -0.590149 -0.842326  1.429461
# 02 L'Air du Desert Marocain - Tauer Perfumes -0.718625 -0.213470  1.429839
#
#                                               Cluster
# perfume
# 02 L'Air du Desert Marocain - Tauer Perfumes        2
# 02 L'Air du Desert Marocain - Tauer Perfumes        1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1
# 02 L'Air du Desert Marocain - Tauer Perfumes        1

# %%
# Initialize the K-Means model using the best value for k
# k_optimal = 4

# Create a scatter plot for PCA data with predicted clusters using hvplot
pca_scatter_plot = pca_cluster_df.hvplot.scatter(
    x='PCA1',
    y='PCA2',
    c='Cluster',
    cmap=['blue', 'pink', 'red', 'purple'],
    colorbar=False,
    title='PCA Scatter Plot with Predicted Clusters',
    xlabel='PCA1',
    ylabel='PCA2',
    legend='top_right',
    scatter_common_params = {
    'legend': 'top_right',
    'width': 400,
    'height': 300,
    'grid': True
})

# Show the plot
pca_scatter_plot
# Out:
# WARNING:param.main: scatter_common_params option not found for scatter plot with bokeh; similar options include: []
# :Scatter   [PCA1]   (PCA2,Cluster)

# %% [markdown]
# 8. Visualize and Compare the Results

# %%
# Composite plot to contrast the Elbow curves
# Arrange plots side by side for comparison
elbow_curve_comparison = elbow_curve_original + elbow_curve_pca

# Show the composite plot
elbow_curve_comparison
# Out:
# :Layout
#    .Curve.I  :Curve   [k]   (inertia)
#    .Curve.II :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
# Arrange plots side by side for comparison
scatter_plots_comparison = original_scatter_plot + pca_scatter_plot

# Show the scatter plot comparison
scatter_plots_comparison
# Out:
# :Layout
#    .Scatter.I  :Scatter   [rating]   (number_votes,predicted_cluster)
#    .Scatter.II :Scatter   [PCA1]   (PCA2,Cluster)
